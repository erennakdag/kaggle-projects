# %%
import numpy as np
import pandas as pd

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# We don't really need the name or the ticket number
df_train.drop(['Name', 'Ticket'], axis=1, inplace=True)
df_train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
df_train.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_train.Cabin.describe()
# Out:
# count         204
# unique        147
# top       B96 B98
# freq            4
# Name: Cabin, dtype: object

# %%
# Check how many of them are survivors
df_train[(df_train.Survived == 1) & (df_train.Cabin.isna())]
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 2              3         1       3  female  26.0      0      0   7.9250   NaN
# 8              9         1       3  female  27.0      0      2  11.1333   NaN
# 9             10         1       2  female  14.0      1      0  30.0708   NaN
# 15            16         1       2  female  55.0      0      0  16.0000   NaN
# 17            18         1       2    male   NaN      0      0  13.0000   NaN
# ..           ...       ...     ...     ...   ...    ...    ...      ...   ...
# 866          867         1       2  female  27.0      1      0  13.8583   NaN
# 869          870         1       3    male   4.0      1      1  11.1333   NaN
# 874          875         1       2  female  28.0      1      0  24.0000   NaN
# 875          876         1       3  female  15.0      0      0   7.2250   NaN
# 880          881         1       2  female  25.0      0      1  26.0000   NaN
#
#     Embarked
# 2          S
# 8          S
# 9          C
# 15         S
# 17         S
# ..       ...
# 866        C
# 869        S
# 874        C
# 875        C
# 880        S
#
# [206 rows x 10 columns]

# %%
# nur 204 von 891 Datenpunkten haben eine Cbain-Info, allerdings sind die NaN-Werte zu dicht mit Survived Fällen. 
# Deshalb können wir versuchen Cabin zu encoden, anstatt komplett rauszunehmen
Cabin_unique_values = df_train.Cabin.unique()
Cabin_encode_table = {}
for index, value in enumerate(Cabin_unique_values):
    Cabin_encode_table[value] = index
    
df_train["Cabin_encoded"] = df_train.Cabin.map(Cabin_encode_table)
df_train.Cabin_encoded.value_counts()
# Out:
# Cabin_encoded
# 0      687
# 8        4
# 4        4
# 73       4
# 54       3
#       ...
# 61       1
# 60       1
# 58       1
# 57       1
# 147      1
# Name: count, Length: 148, dtype: int64

# %%
# Now we can encode other non-numerical columns Sex and Embarked accordingly
Embarked_unique_values = df_train.Embarked.unique()
Embarked_encode_table = {}
for index, value in enumerate(Embarked_unique_values):
    Embarked_encode_table[value] = index
    
Sex_unique_values = df_train.Sex.unique()
Sex_encode_table = {}
for index, value in enumerate(Sex_unique_values):
    Sex_encode_table[value] = index
    
df_train["Embarked_encoded"] = df_train.Embarked.map(Embarked_encode_table)
df_train["Sex_encoded"] = df_train.Sex.map(Sex_encode_table)

# %%
df_train.Embarked_encoded.value_counts()
# Out:
# Embarked_encoded
# 0    644
# 1    168
# 2     77
# 3      2
# Name: count, dtype: int64

# %%
df_train.Sex_encoded.value_counts()
# Out:
# Sex_encoded
# 0    577
# 1    314
# Name: count, dtype: int64

# %%
# Age also needs to be filled, because it has some NaN values
df_train.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# So lets fill it with the mean
df_train.Age.fillna(df_train.Age.mean(), inplace=True)

# %%
# One last look at the training data before scaling
df_train.head(10)
# Out:
#    PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.000000      1      0   7.2500
# 1            2         1       1  female  38.000000      1      0  71.2833
# 2            3         1       3  female  26.000000      0      0   7.9250
# 3            4         1       1  female  35.000000      1      0  53.1000
# 4            5         0       3    male  35.000000      0      0   8.0500
# 5            6         0       3    male  29.699118      0      0   8.4583
# 6            7         0       1    male  54.000000      0      0  51.8625
# 7            8         0       3    male   2.000000      3      1  21.0750
# 8            9         1       3  female  27.000000      0      2  11.1333
# 9           10         1       2  female  14.000000      1      0  30.0708
#
#   Cabin Embarked  Cabin_encoded  Embarked_encoded  Sex_encoded
# 0   NaN        S              0                 0            0
# 1   C85        C              1                 1            1
# 2   NaN        S              0                 0            1
# 3  C123        S              2                 0            1
# 4   NaN        S              0                 0            0
# 5   NaN        Q              0                 2            0
# 6   E46        S              3                 0            0
# 7   NaN        S              0                 0            0
# 8   NaN        S              0                 0            1
# 9   NaN        C              0                 1            1

# %%
# Some columns we don't need anymore
df_train_data = df_train.drop(["PassengerId", "Sex", "Cabin", "Embarked"], axis=1)
df_train_data.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Cabin_encoded  \
# 0         0       3  22.0      1      0   7.2500              0
# 1         1       1  38.0      1      0  71.2833              1
# 2         1       3  26.0      0      0   7.9250              0
# 3         1       1  35.0      1      0  53.1000              2
# 4         0       3  35.0      0      0   8.0500              0
#
#    Embarked_encoded  Sex_encoded
# 0                 0            0
# 1                 1            1
# 2                 0            1
# 3                 0            1
# 4                 0            0

# %%
df_train_labels = df_train_data.Survived

scaler = MinMaxScaler()
df_train_scaled = pd.DataFrame(
    scaler.fit_transform(df_train_data.drop(['Survived'], axis=1)),
    columns=df_train_data.columns[1:] # Because we don't have Survived anymore
)

# %%
df_train_scaled.head()
# Out:
#    Pclass       Age  SibSp  Parch      Fare  Cabin_encoded  Embarked_encoded  \
# 0     1.0  0.271174  0.125    0.0  0.014151       0.000000          0.000000
# 1     0.0  0.472229  0.125    0.0  0.139136       0.006803          0.333333
# 2     1.0  0.321438  0.000    0.0  0.015469       0.000000          0.000000
# 3     0.0  0.434531  0.125    0.0  0.103644       0.013605          0.000000
# 4     1.0  0.434531  0.000    0.0  0.015713       0.000000          0.000000
#
#    Sex_encoded
# 0          0.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          0.0

# %%
df_train_scaled.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.654321    0.367921    0.065376    0.063599    0.062858
# std      0.418036    0.163383    0.137843    0.134343    0.096995
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.500000    0.271174    0.000000    0.000000    0.015440
# 50%      1.000000    0.367921    0.000000    0.000000    0.028213
# 75%      1.000000    0.434531    0.125000    0.000000    0.060508
# max      1.000000    1.000000    1.000000    1.000000    1.000000
#
#        Cabin_encoded  Embarked_encoded  Sex_encoded
# count     891.000000        891.000000   891.000000
# mean        0.105629          0.122709     0.352413
# std         0.238073          0.215867     0.477990
# min         0.000000          0.000000     0.000000
# 25%         0.000000          0.000000     0.000000
# 50%         0.000000          0.000000     0.000000
# 75%         0.000000          0.333333     1.000000
# max         1.000000          1.000000     1.000000

# %%
# Let's train the model now
model = RandomForestClassifier(random_state=42)
model.fit(df_train_scaled, df_train_labels)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Looking at the feature importance
for column_name, feature_importance in zip(df_train_scaled.columns, model.feature_importances_):
    print(column_name, feature_importance, sep=':')
# Out:
# Pclass:0.06918017863455934
# Age:0.23610622269181258
# SibSp:0.04647740370130991
# Parch:0.03717060852431524
# Fare:0.2343029472451507
# Cabin_encoded:0.09628262417583099
# Embarked_encoded:0.03291349151813235
# Sex_encoded:0.24756652350888889

# %%
# Looking at the score
model.score(df_train_scaled, df_train_labels)
# Out:
# 0.9865319865319865

# %%
conf_mtx = confusion_matrix(df_train_labels, model.predict(df_train_scaled))
conf_mtx
# Out:
# array([[547,   2],
#        [ 10, 332]], dtype=int64)

# %%
# Now testing the model
df_test = pd.read_csv('test.csv')
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df_test.Cabin.describe()
# Out:
# count                  91
# unique                 76
# top       B57 B59 B63 B66
# freq                    3
# Name: Cabin, dtype: object

# %%
# We need to encode again
last_idx_counter = len(Cabin_unique_values)
for value in df_test.Cabin.unique():
    if Cabin_encode_table.get(value, -1) == -1:
        Cabin_encode_table[value] = last_idx_counter
        last_idx_counter += 1

last_idx_counter = len(Embarked_unique_values)
for value in df_test.Embarked.unique():
    if Embarked_encode_table.get(value, -1) == -1:
        Embarked_encode_table[value] = last_idx_counter
        last_idx_counter += 1
        
df_test["Cabin_encoded"] = df_test.Cabin.map(Cabin_encode_table)
df_test["Embarked_encoded"] = df_test.Embarked.map(Embarked_encode_table)
df_test["Sex_encoded"] = df_test.Sex.map(Sex_encode_table)

# %%
df_test.Cabin_encoded.value_counts()
# Out:
# Cabin_encoded
# 0      327
# 59       3
# 174      2
# 160      2
# 173      2
#       ...
# 169      1
# 170      1
# 22       1
# 120      1
# 186      1
# Name: count, Length: 77, dtype: int64

# %%
df_test.Embarked_encoded.value_counts()
# Out:
# Embarked_encoded
# 0    270
# 1    102
# 2     46
# Name: count, dtype: int64

# %%
df_test.Sex_encoded.value_counts()
# Out:
# Sex_encoded
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
# Lets fill age with the mean again
df_test.Age.describe()
# Out:
# count    332.000000
# mean      30.272590
# std       14.181209
# min        0.170000
# 25%       21.000000
# 50%       27.000000
# 75%       39.000000
# max       76.000000
# Name: Age, dtype: float64

# %%
df_train.Age.mean(), df_test.Age.mean()
# Out:
# (29.69911764705882, 30.272590361445783)

# %%
# We fill it with the mean from the training data
df_test.Age.fillna(df_train.Age.mean(), inplace=True)

# We should also fill the NaN values in other columns with 0
df_test.fillna(0, inplace=True)
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Cabin_encoded  \
# 0  34.5      0      0   330911   7.8292     0        Q              0
# 1  47.0      1      0   363272   7.0000     0        S              0
# 2  62.0      0      0   240276   9.6875     0        Q              0
# 3  27.0      0      0   315154   8.6625     0        S              0
# 4  22.0      1      1  3101298  12.2875     0        S              0
#
#    Embarked_encoded  Sex_encoded
# 0                 2            0
# 1                 0            1
# 2                 2            0
# 3                 0            0
# 4                 0            1

# %%
# Now lets drop some columns and scale the data
df_test_scaled = pd.DataFrame(
    scaler.transform(df_test.drop(["PassengerId", "Name", "Sex", "Ticket", "Cabin", "Embarked"], axis=1)),
    columns=df_train_scaled.columns
)
df_test_scaled.head()
# Out:
#    Pclass       Age  SibSp     Parch      Fare  Cabin_encoded  \
# 0     1.0  0.428248  0.000  0.000000  0.015282            0.0
# 1     1.0  0.585323  0.125  0.000000  0.013663            0.0
# 2     0.5  0.773813  0.000  0.000000  0.018909            0.0
# 3     1.0  0.334004  0.000  0.000000  0.016908            0.0
# 4     1.0  0.271174  0.125  0.166667  0.023984            0.0
#
#    Embarked_encoded  Sex_encoded
# 0          0.666667          0.0
# 1          0.000000          1.0
# 2          0.666667          0.0
# 3          0.000000          0.0
# 4          0.000000          1.0

# %%
df_test_scaled.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare  \
# count  418.000000  418.000000  418.000000  418.000000  418.000000
# mean     0.632775    0.373644    0.055921    0.065391    0.069373
# std      0.420919    0.158792    0.112095    0.163571    0.109046
# min      0.000000   -0.003141    0.000000    0.000000    0.000000
# 25%      0.000000    0.283740    0.000000    0.000000    0.015412
# 50%      1.000000    0.367921    0.000000    0.000000    0.028213
# 75%      1.000000    0.443956    0.125000    0.000000    0.061429
# max      1.000000    0.949736    1.000000    1.500000    1.000000
#
#        Cabin_encoded  Embarked_encoded  Sex_encoded
# count     418.000000        418.000000   418.000000
# mean        0.170605          0.154705     0.363636
# std         0.374628          0.228505     0.481622
# min         0.000000          0.000000     0.000000
# 25%         0.000000          0.000000     0.000000
# 50%         0.000000          0.000000     0.000000
# 75%         0.000000          0.333333     1.000000
# max         1.265306          0.666667     1.000000

# %%
df_test.Fare.unique()
# Out:
# array([  7.8292,   7.    ,   9.6875,   8.6625,  12.2875,   9.225 ,
#          7.6292,  29.    ,   7.2292,  24.15  ,   7.8958,  26.    ,
#         82.2667,  61.175 ,  27.7208,  12.35  ,   7.225 ,   7.925 ,
#         59.4   ,   3.1708,  31.6833,  61.3792, 262.375 ,  14.5   ,
#         61.9792,  30.5   ,  21.6792,  31.5   ,  20.575 ,  23.45  ,
#         57.75  ,   8.05  ,   9.5   ,  56.4958,  13.4167,  26.55  ,
#          7.85  ,  13.    ,  52.5542,  29.7   ,   7.75  ,  76.2917,
#         15.9   ,  60.    ,  15.0333,  23.    , 263.    ,  15.5792,
#         29.125 ,   7.65  ,  16.1   ,  13.5   ,   7.725 ,  21.    ,
#          7.8792,  42.4   ,  28.5375, 211.5   ,  25.7   ,  15.2458,
#        221.7792,  10.7083,  14.4542,  13.9   ,   7.775 ,  52.    ,
#          7.7958,  78.85  ,   7.8542,  55.4417,   8.5167,  22.525 ,
#          7.8208,   8.7125,  15.0458,   7.7792,  31.6792,   7.2833,
#          6.4375,  16.7   ,  75.2417,  15.75  ,   7.25  ,  23.25  ,
#         28.5   ,  25.4667,  46.9   , 151.55  ,  18.    ,  51.8625,
#         83.1583,   0.    ,  12.1833,  31.3875,   7.55  ,  13.775 ,
#          7.7333,  22.025 ,  50.4958,  34.375 ,   8.9625,  39.    ,
#         36.75  ,  53.1   , 247.5208,  16.    ,  69.55  ,  32.5   ,
#        134.5   ,  10.5   ,   8.1125,  15.5   ,  14.4   , 227.525 ,
#         25.7417,   7.05  ,  73.5   ,  42.5   , 164.8667,  13.8583,
#         27.4458,  15.1   ,  65.    ,   6.4958,  71.2833,  75.25  ,
#        106.425 ,  30.    ,   7.8875,  27.75  , 136.7792,   9.325 ,
#         17.4   ,  12.7375,  20.2125,  39.6   ,   6.95  ,  81.8583,
#         41.5792,  45.5   ,   9.35  ,  93.5   ,  14.1083,   7.575 ,
#        135.6333, 146.5208, 211.3375,  79.2   ,  15.7417,   7.5792,
#        512.3292,  63.3583,  51.4792,  15.55  ,  37.0042,  14.4583,
#         39.6875,  11.5   ,  50.    ,  12.875 ,  21.075 ,  39.4   ,
#         20.25  ,  47.1   ,  13.8625,   7.7208,  90.    , 108.9   ,
#         22.3583])

# %%
prediction_probas = model.predict_proba(df_test_scaled)
prediction_probas
# Out:
# array([[0.98825758, 0.01174242],
#        [0.75      , 0.25      ],
#        [0.74      , 0.26      ],
#        [0.26      , 0.74      ],
#        [0.59      , 0.41      ],
#        [0.85      , 0.15      ],
#        [0.67111111, 0.32888889],
#        [0.91      , 0.09      ],
#        [0.17      , 0.83      ],
#        [0.97      , 0.03      ],
#        [1.        , 0.        ],
#        [0.73      , 0.27      ],
#        [0.07      , 0.93      ],
#        [0.87      , 0.13      ],
#        [0.07      , 0.93      ],
#        [0.04      , 0.96      ],
#        [0.87      , 0.13      ],
#        [0.45      , 0.55      ],
#        [0.715     , 0.285     ],
#        [0.52      , 0.48      ],
#        [0.73      , 0.27      ],
#        [0.48      , 0.52      ],
#        [0.05      , 0.95      ],
#        [0.69      , 0.31      ],
#        [0.09      , 0.91      ],
#        [0.98      , 0.02      ],
#        [0.01      , 0.99      ],
#        [0.34      , 0.66      ],
#        [0.37      , 0.63      ],
#        [0.79      , 0.21      ],
#        [0.99      , 0.01      ],
#        [0.97      , 0.03      ],
#        [0.39      , 0.61      ],
#        [0.88      , 0.12      ],
#        [0.379     , 0.621     ],
#        [0.44      , 0.56      ],
#        [0.97      , 0.03      ],
#        [0.86      , 0.14      ],
#        [0.97      , 0.03      ],
#        [0.38133333, 0.61866667],
#        [0.7375    , 0.2625    ],
#        [0.49      , 0.51      ],
#        [0.901     , 0.099     ],
#        [0.        , 1.        ],
#        [0.        , 1.        ],
#        [0.97285714, 0.02714286],
#        [0.33      , 0.67      ],
#        [0.87268841, 0.12731159],
#        [0.04      , 0.96      ],
#        [0.47      , 0.53      ],
#        [0.62      , 0.38      ],
#        [0.91      , 0.09      ],
#        [0.17      , 0.83      ],
#        [0.14      , 0.86      ],
#        [0.85      , 0.15      ],
#        [0.95      , 0.05      ],
#        [1.        , 0.        ],
#        [0.78      , 0.22      ],
#        [1.        , 0.        ],
#        [0.01      , 0.99      ],
#        [0.945     , 0.055     ],
#        [0.77      , 0.23      ],
#        [0.96      , 0.04      ],
#        [0.19      , 0.81      ],
#        [0.46      , 0.54      ],
#        [0.05      , 0.95      ],
#        [0.21      , 0.79      ],
#        [0.84      , 0.16      ],
#        [0.24      , 0.76      ],
#        [0.27      , 0.73      ],
#        [0.23756818, 0.76243182],
#        [0.99      , 0.01      ],
#        [0.8       , 0.2       ],
#        [0.2       , 0.8       ],
#        [0.01      , 0.99      ],
#        [0.45      , 0.55      ],
#        [1.        , 0.        ],
#        [0.17      , 0.83      ],
#        [0.94      , 0.06      ],
#        [0.23756818, 0.76243182],
#        [0.2       , 0.8       ],
#        [0.69      , 0.31      ],
#        [0.75      , 0.25      ],
#        [1.        , 0.        ],
#        [0.75      , 0.25      ],
#        [0.94      , 0.06      ],
#        [0.02      , 0.98      ],
#        [0.71      , 0.29      ],
#        [0.12149877, 0.87850123],
#        [0.14      , 0.86      ],
#        [0.69      , 0.31      ],
#        [0.60316667, 0.39683333],
#        [0.06      , 0.94      ],
#        [1.        , 0.        ],
#        [0.69      , 0.31      ],
#        [0.87      , 0.13      ],
#        [0.11      , 0.89      ],
#        [0.69885714, 0.30114286],
#        [0.58      , 0.42      ],
#        [0.99833333, 0.00166667],
#        [0.01      , 0.99      ],
#        [0.87      , 0.13      ],
#        [0.87268841, 0.12731159],
#        [0.965     , 0.035     ],
#        [0.52      , 0.48      ],
#        [0.96      , 0.04      ],
#        [0.53623737, 0.46376263],
#        [0.87268841, 0.12731159],
#        [0.76      , 0.24      ],
#        [0.53      , 0.47      ],
#        [0.87166667, 0.12833333],
#        [0.05130297, 0.94869703],
#        [0.05      , 0.95      ],
#        [0.57      , 0.43      ],
#        [0.08      , 0.92      ],
#        [0.74      , 0.26      ],
#        [0.95      , 0.05      ],
#        [0.33      , 0.67      ],
#        [0.45      , 0.55      ],
#        [0.        , 1.        ],
#        [0.17      , 0.83      ],
#        [0.97092632, 0.02907368],
#        [0.01      , 0.99      ],
#        [0.91      , 0.09      ],
#        [0.87268841, 0.12731159],
#        [0.34      , 0.66      ],
#        [0.83      , 0.17      ],
#        [0.03      , 0.97      ],
#        [0.54371429, 0.45628571],
#        [0.995     , 0.005     ],
#        [0.8655    , 0.1345    ],
#        [0.32      , 0.68      ],
#        [0.89      , 0.11      ],
#        [0.95      , 0.05      ],
#        [0.95333333, 0.04666667],
#        [0.99      , 0.01      ],
#        [0.84      , 0.16      ],
#        [0.99      , 0.01      ],
#        [0.86      , 0.14      ],
#        [0.933     , 0.067     ],
#        [0.91      , 0.09      ],
#        [0.01      , 0.99      ],
#        [0.73      , 0.27      ],
#        [0.99      , 0.01      ],
#        [0.255     , 0.745     ],
#        [0.88      , 0.12      ],
#        [0.904     , 0.096     ],
#        [0.995     , 0.005     ],
#        [0.15      , 0.85      ],
#        [0.84      , 0.16      ],
#        [0.02      , 0.98      ],
#        [0.95657143, 0.04342857],
#        [0.97      , 0.03      ],
#        [0.41      , 0.59      ],
#        [0.93      , 0.07      ],
#        [0.91      , 0.09      ],
#        [0.1       , 0.9       ],
#        [0.52      , 0.48      ],
#        [0.32      , 0.68      ],
#        [0.21      , 0.79      ],
#        [0.01763492, 0.98236508],
#        [0.22      , 0.78      ],
#        [0.45      , 0.55      ],
#        [0.77      , 0.23      ],
#        [0.54871429, 0.45128571],
#        [0.71      , 0.29      ],
#        [0.43      , 0.57      ],
#        [0.968     , 0.032     ],
#        [0.08      , 0.92      ],
#        [0.86      , 0.14      ],
#        [0.91933333, 0.08066667],
#        [0.82      , 0.18      ],
#        [0.95      , 0.05      ],
#        [0.83537698, 0.16462302],
#        [0.93      , 0.07      ],
#        [0.06      , 0.94      ],
#        [0.04      , 0.96      ],
#        [0.3       , 0.7       ],
#        [0.11      , 0.89      ],
#        [0.09      , 0.91      ],
#        [0.94      , 0.06      ],
#        [0.36      , 0.64      ],
#        [0.06      , 0.94      ],
#        [0.87268841, 0.12731159],
#        [0.08      , 0.92      ],
#        [0.97      , 0.03      ],
#        [0.09      , 0.91      ],
#        [0.8025    , 0.1975    ],
#        [0.97      , 0.03      ],
#        [0.94833333, 0.05166667],
#        [0.93      , 0.07      ],
#        [0.77      , 0.23      ],
#        [0.35      , 0.65      ],
#        [0.87      , 0.13      ],
#        [0.24      , 0.76      ],
#        [0.7       , 0.3       ],
#        [0.38      , 0.62      ],
#        [0.69      , 0.31      ],
#        [0.97166667, 0.02833333],
#        [0.95      , 0.05      ],
#        [0.37      , 0.63      ],
#        [0.15      , 0.85      ],
#        [0.38      , 0.62      ],
#        [0.07      , 0.93      ],
#        [0.98833333, 0.01166667],
#        [0.76      , 0.24      ],
#        [0.74245661, 0.25754339],
#        [0.98833333, 0.01166667],
#        [0.06      , 0.94      ],
#        [1.        , 0.        ],
#        [0.8675    , 0.1325    ],
#        [0.99      , 0.01      ],
#        [0.98      , 0.02      ],
#        [0.48      , 0.52      ],
#        [0.45      , 0.55      ],
#        [0.61      , 0.39      ],
#        [0.01      , 0.99      ],
#        [0.73      , 0.27      ],
#        [0.08      , 0.92      ],
#        [1.        , 0.        ],
#        [0.09      , 0.91      ],
#        [0.995     , 0.005     ],
#        [0.01      , 0.99      ],
#        [0.33      , 0.67      ],
#        [0.19      , 0.81      ],
#        [0.71      , 0.29      ],
#        [0.92      , 0.08      ],
#        [0.12149877, 0.87850123],
#        [0.94583333, 0.05416667],
#        [0.99      , 0.01      ],
#        [0.88      , 0.12      ],
#        [0.04      , 0.96      ],
#        [0.86      , 0.14      ],
#        [0.92357237, 0.07642763],
#        [0.65      , 0.35      ],
#        [1.        , 0.        ],
#        [0.51      , 0.49      ],
#        [0.36      , 0.64      ],
#        [0.29      , 0.71      ],
#        [0.04      , 0.96      ],
#        [0.21      , 0.79      ],
#        [0.08      , 0.92      ],
#        [0.69      , 0.31      ],
#        [0.98      , 0.02      ],
#        [0.99      , 0.01      ],
#        [0.55      , 0.45      ],
#        [0.18      , 0.82      ],
#        [0.91      , 0.09      ],
#        [0.        , 1.        ],
#        [0.78      , 0.22      ],
#        [0.04      , 0.96      ],
#        [0.99      , 0.01      ],
#        [0.48      , 0.52      ],
#        [0.99      , 0.01      ],
#        [0.8215    , 0.1785    ],
#        [0.91933333, 0.08066667],
#        [0.87268841, 0.12731159],
#        [0.98      , 0.02      ],
#        [0.43      , 0.57      ],
#        [0.9       , 0.1       ],
#        [0.98      , 0.02      ],
#        [0.95      , 0.05      ],
#        [0.09      , 0.91      ],
#        [0.08      , 0.92      ],
#        [0.6       , 0.4       ],
#        [1.        , 0.        ],
#        [0.98      , 0.02      ],
#        [0.91933333, 0.08066667],
#        [0.97      , 0.03      ],
#        [0.99      , 0.01      ],
#        [0.52      , 0.48      ],
#        [0.87268841, 0.12731159],
#        [0.06      , 0.94      ],
#        [0.03      , 0.97      ],
#        [1.        , 0.        ],
#        [0.04      , 0.96      ],
#        [1.        , 0.        ],
#        [0.97      , 0.03      ],
#        [0.89      , 0.11      ],
#        [0.945     , 0.055     ],
#        [0.91      , 0.09      ],
#        [0.12      , 0.88      ],
#        [0.12149877, 0.87850123],
#        [0.79      , 0.21      ],
#        [0.24      , 0.76      ],
#        [1.        , 0.        ],
#        [1.        , 0.        ],
#        [0.69      , 0.31      ],
#        [0.79351587, 0.20648413],
#        [1.        , 0.        ],
#        [0.93      , 0.07      ],
#        [0.78111111, 0.21888889],
#        [0.83537698, 0.16462302],
#        [0.68      , 0.32      ],
#        [0.93      , 0.07      ],
#        [1.        , 0.        ],
#        [0.08      , 0.92      ],
#        [0.79      , 0.21      ],
#        [0.93      , 0.07      ],
#        [0.91333333, 0.08666667],
#        [0.64      , 0.36      ],
#        [0.73      , 0.27      ],
#        [0.82285714, 0.17714286],
#        [0.92      , 0.08      ],
#        [0.12149877, 0.87850123],
#        [0.18      , 0.82      ],
#        [0.43666667, 0.56333333],
#        [0.28      , 0.72      ],
#        [0.57      , 0.43      ],
#        [0.85      , 0.15      ],
#        [0.9       , 0.1       ],
#        [0.34      , 0.66      ],
#        [0.91933333, 0.08066667],
#        [0.75745661, 0.24254339],
#        [0.01      , 0.99      ],
#        [0.13      , 0.87      ],
#        [0.6       , 0.4       ],
#        [0.58      , 0.42      ],
#        [0.76      , 0.24      ],
#        [0.96      , 0.04      ],
#        [0.965     , 0.035     ],
#        [0.7975    , 0.2025    ],
#        [0.46      , 0.54      ],
#        [0.09      , 0.91      ],
#        [0.06      , 0.94      ],
#        [0.98      , 0.02      ],
#        [0.03      , 0.97      ],
#        [0.8       , 0.2       ],
#        [0.69      , 0.31      ],
#        [0.98      , 0.02      ],
#        [0.1       , 0.9       ],
#        [0.25      , 0.75      ],
#        [1.        , 0.        ],
#        [0.56      , 0.44      ],
#        [0.84      , 0.16      ],
#        [0.7       , 0.3       ],
#        [0.57      , 0.43      ],
#        [0.8602381 , 0.1397619 ],
#        [0.91      , 0.09      ],
#        [0.83537698, 0.16462302],
#        [0.67833333, 0.32166667],
#        [0.74416667, 0.25583333],
#        [0.92666667, 0.07333333],
#        [0.04      , 0.96      ],
#        [0.79      , 0.21      ],
#        [0.255     , 0.745     ],
#        [0.99      , 0.01      ],
#        [0.5       , 0.5       ],
#        [1.        , 0.        ],
#        [0.05      , 0.95      ],
#        [0.06      , 0.94      ],
#        [0.98833333, 0.01166667],
#        [1.        , 0.        ],
#        [0.8625    , 0.1375    ],
#        [0.24      , 0.76      ],
#        [0.38      , 0.62      ],
#        [0.11      , 0.89      ],
#        [0.94666667, 0.05333333],
#        [0.87268841, 0.12731159],
#        [0.13      , 0.87      ],
#        [1.        , 0.        ],
#        [0.12      , 0.88      ],
#        [0.05      , 0.95      ],
#        [0.26      , 0.74      ],
#        [0.01      , 0.99      ],
#        [0.65      , 0.35      ],
#        [0.94      , 0.06      ],
#        [0.6       , 0.4       ],
#        [0.13      , 0.87      ],
#        [0.41      , 0.59      ],
#        [0.96916667, 0.03083333],
#        [0.01      , 0.99      ],
#        [0.77      , 0.23      ],
#        [0.57071429, 0.42928571],
#        [0.04      , 0.96      ],
#        [0.03      , 0.97      ],
#        [0.83      , 0.17      ],
#        [0.93083333, 0.06916667],
#        [0.6       , 0.4       ],
#        [0.65      , 0.35      ],
#        [0.87268841, 0.12731159],
#        [0.55431929, 0.44568071],
#        [0.49      , 0.51      ],
#        [0.65      , 0.35      ],
#        [0.38      , 0.62      ],
#        [0.03      , 0.97      ],
#        [0.925     , 0.075     ],
#        [0.99      , 0.01      ],
#        [0.4937969 , 0.5062031 ],
#        [0.9       , 0.1       ],
#        [0.59      , 0.41      ],
#        [0.07      , 0.93      ],
#        [0.48      , 0.52      ],
#        [0.88      , 0.12      ],
#        [0.97      , 0.03      ],
#        [0.07      , 0.93      ],
#        [0.98      , 0.02      ],
#        [0.03      , 0.97      ],
#        [0.99      , 0.01      ],
#        [1.        , 0.        ],
#        [0.07      , 0.93      ],
#        [1.        , 0.        ],
#        [0.09      , 0.91      ],
#        [0.74      , 0.26      ],
#        [0.27      , 0.73      ],
#        [0.43      , 0.57      ],
#        [0.96833333, 0.03166667],
#        [0.54      , 0.46      ],
#        [0.07763492, 0.92236508],
#        [0.14      , 0.86      ],
#        [0.12149877, 0.87850123],
#        [0.02      , 0.98      ],
#        [0.72      , 0.28      ],
#        [1.        , 0.        ],
#        [0.01      , 0.99      ],
#        [0.99      , 0.01      ],
#        [1.        , 0.        ],
#        [0.38      , 0.62      ]])

# %%
prediction_survived = np.array(
    list(
        map(
            int,
            [entry[1] > entry[0] for entry in prediction_probas]
        )
    )
)

df_test["NotSurvivedProba"] = prediction_probas[:, 0]
df_test["SurvivedProba"] = prediction_probas[:, 1]
df_test["Survived"] = prediction_survived

# %%
submission = df_test[["PassengerId", "Survived"]]
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         1
# 4          896         0

# %%
submission.to_csv("submission_erennakdag.csv", index=False)
